# %%
import vocab
import pandas as pd

v = vocab.VocabDatabase("vocab_list.txt", delimiter="|")

# %%
df = v.database
df
# Out:
#         vocab  type     gender definition  numbering
# 0        Buch  noun        das       Book          0
# 1     schnell   adj        NaN       fast          1
# 2     langsam   adj        NaN       slow          2
# 3  vorstellen  verb  introduce        NaN          3
# 4     stellen  verb        put        NaN          4

# %%
import numpy as np
print(np.random.rand(10))
# Out:
# [0.96347071 0.54517226 0.57783856 0.216273   0.91345978 0.318355
#  0.37073709 0.96797181 0.89606408 0.75507613]

# %%
np.prompt()
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Cell In[5], line 1
# ----> 1 np.prompt()
#
# File ~/miniconda3/envs/jax/lib/python3.13/site-packages/numpy/__init__.py:414, in __getattr__(attr)
#     411     import numpy.char as char
#     412     return char.chararray
# --> 414 raise AttributeError("module {!r} has no attribute "
#     415                      "{!r}".format(__name__, attr))
#
# AttributeError: module 'numpy' has no attribute 'prompt'
